# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Slider', 'Fastball', 'Curveball', 'Changeup']
feb_pitches = [13, 13, 9, 1]
feb_spots = [8, 5, 3, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [66, 35, 32, 4]
mar_spots = [51, 14, 19, 2]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [79, 51, 26, 1]
apr_spots = [43, 19, 11, 0]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 10), gridspec_kw={'hspace': 0.4})
fig.suptitle("Gio Arzuaga Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Slider', 'Changeup', 'Cutter', 'Splitter']
feb_pitches = [22, 5, 6, 0, 0]
feb_spots = [16, 2, 2, 0, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [167, 64, 44, 0, 2]
mar_spots = [116, 46, 16, 0, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [192, 97, 49, 0, 1]
apr_spots = [109, 46, 28, 0, 1]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [69, 31, 7, 9, 0]
may_spots = [43, 23, 3, 7, 0]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 8), gridspec_kw={'hspace': 0.2, 'wspace': 0.1})
fig.suptitle("Hunter Bell Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Changeup', 'Curveball']
feb_pitches = [50, 26, 21]
feb_spots = [25, 13, 11]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
#mar_pitches = [1, 1, 1]
#mar_spots = [1, 1, 1]

#mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

#mar_total_pitches = sum(mar_pitches)
#mar_total_spots = sum(mar_spots)
#mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

#mar_df = pd.DataFrame({
    #'Pitch Type': pitch_types + ['Totals'],
    #'Pitches': mar_pitches + [mar_total_pitches],
    #'Spots': mar_spots + [mar_total_spots],
    #'Spot%': mar_spot_percentages + [mar_total_percent]
#})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
#mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 1, figsize=(10, 8), gridspec_kw={'hspace': 0.6})
fig.suptitle("Zach Brockner Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
#table(axs[2], mar_df, "March")
table(axs[1], season_df, "Season")

axs[2].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Changeup', 'Slider']
feb_pitches = [20, 19, 4]
feb_spots = [14, 12, 3]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [107, 75, 18]
mar_spots = [66, 45, 10]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [129, 54, 10]
apr_spots = [87, 33, 1]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [12, 5, 1]
may_spots = [7, 5, 0]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.6, 'wspace': 0.1})
fig.suptitle("Max Brulport Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Curveball', 'Cutter', 'Changeup']
feb_pitches = [43, 23, 17, 8]
feb_spots = [23, 15, 11, 3]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [31, 20, 8, 0]
mar_spots = [14, 12, 6, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 1, figsize=(10, 8), gridspec_kw={'hspace': 0.4})
fig.suptitle("TJ Curley Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Slider', 'Changeup']
feb_pitches = [22, 20, 6]
feb_spots = [17, 7, 1]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [113, 49, 22]
mar_spots = [72, 22, 10]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [79, 86, 17]
apr_spots = [49, 59, 10]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [6, 3, 1]
may_spots = [3, 2, 0]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.6, 'wspace': 0.1})
fig.suptitle("Luke Dellentash Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Changeup', 'Slider', 'Curveball']
feb_pitches = [68, 49, 48, 2]
feb_spots = [50, 27, 30, 2]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [158, 114, 74, 9]
mar_spots = [112, 76, 56, 2]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 1, figsize=(10, 8), gridspec_kw={'hspace': 0.4})
fig.suptitle("Ryan Douglas Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Slider', 'Changeup']
feb_pitches = [7, 6, 4]
feb_spots = [5, 4, 3]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [122, 72, 30]
mar_spots = [66, 39, 12]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [71, 34, 7]
apr_spots = [41, 16, 2]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 8), gridspec_kw={'hspace': 0.4})
fig.suptitle("Josh Florence Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Slider', 'Two-Seam', 'Curveball', 'Splitter']
feb_pitches = [28, 17, 15, 9, 1]
feb_spots = [12, 11, 6, 4, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [186, 152, 67, 40, 14]
mar_spots = [101, 99, 41, 14, 5]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [181, 142, 36, 32, 21]
apr_spots = [113, 95, 22, 18, 9]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [42, 33, 5, 9, 5]
may_spots = [27, 25, 3, 4, 3]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 8), gridspec_kw={'hspace': 0.2, 'wspace': 0.1})
fig.suptitle("Jimmy Gilleran Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Slider', 'Curveball', 'Cutter', 'Fastball']
feb_pitches = [0, 0, 0, 0]
feb_spots = [0, 0, 0, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [13, 19, 13, 0]
mar_spots = [8, 10, 9, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [86, 51, 33, 1]
apr_spots = [55, 31, 21, 1]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [6, 12, 10, 0]
may_spots = [0, 7, 3, 0]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

#feb_total_pitches = sum(feb_pitches)
#feb_total_spots = sum(feb_spots)
#feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 10), gridspec_kw={'hspace': 0.3})
fig.suptitle("Mason Hebert Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

#table(axs[0], feb_df, "February")
table(axs[0], mar_df, "March")
table(axs[1], apr_df, "April")
table(axs[2], may_df, "May")
table(axs[3], season_df, "Season")


plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Changeup', 'Slider']
feb_pitches = [18, 11, 6]
feb_spots = [10, 6, 2]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [143, 92, 25]
mar_spots = [86, 44, 13]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [148, 51, 46]
apr_spots = [80, 28, 28]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [42, 11, 13]
may_spots = [25, 7, 6]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.6, 'wspace': 0.1})
fig.suptitle("Jake Lanzer Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Changeup', 'Slider']
feb_pitches = [13, 25, 10]
feb_spots = [10, 18, 8]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [106, 84, 29]
mar_spots = [71, 48, 12]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [102, 61, 32]
apr_spots = [71, 34, 16]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [23, 5, 6]
may_spots = [16, 2, 5]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.6, 'wspace': 0.1})
fig.suptitle("Adam Martin Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Two-Seam', 'Slider', 'Curveball', 'Splitter']
feb_pitches = [7, 6, 1, 4, 1]
feb_spots = [4, 3, 1, 2, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [31, 0, 3, 0, 0]
mar_spots = [15, 0, 0, 0, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [11, 0, 0, 12, 1]
apr_spots = [9, 0, 0, 10, 0]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 10), gridspec_kw={'hspace': 0.2})
fig.suptitle("Frankie Melendez Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.5)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Curveball', 'Changeup']
feb_pitches = [10, 13, 4]
feb_spots = [6, 9, 1]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [77, 25, 19]
mar_spots = [49, 14, 13]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [46, 25, 9]
apr_spots = [25, 14, 4]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 8), gridspec_kw={'hspace': 0.4})
fig.suptitle("Anthony Michaud Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Cutter', 'Curveball', 'Changeup']
feb_pitches = [15, 3, 10, 1]
feb_spots = [6, 2, 5, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [10, 6, 5, 0]
mar_spots = [5, 5, 3, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [33, 39, 14, 10]
apr_spots = [26, 19, 4, 9]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [4, 3, 0, 0]
may_spots = [3, 1, 0, 0]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.3, 'wspace': 0.1})
fig.suptitle("Rob Moynihan Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Cutter', 'Curveball', 'Changeup']
feb_pitches = [29, 25, 6, 0]
feb_spots = [20, 17, 1, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [33, 30, 6, 0]
mar_spots = [12, 16, 0, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [65, 60, 22, 1]
apr_spots = [33, 41, 10, 0]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 10), gridspec_kw={'hspace': 0.4})
fig.suptitle("Justin Tullish Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Splitter', 'Slider', 'Two-Seam']
feb_pitches = [5, 1, 1, 0]
feb_spots = [2, 1, 0, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [42, 2, 3, 0]
mar_spots = [20, 0, 0, 0]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [66, 56, 23, 23]
apr_spots = [37, 32, 4, 7]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(4, 1, figsize=(10, 10), gridspec_kw={'hspace': 0.4})
fig.suptitle("Tanyon Weber Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0], feb_df, "February")
table(axs[1], mar_df, "March")
table(axs[2], apr_df, "April")
table(axs[3], season_df, "Season")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#CHANGE THESE
pitch_types = ['Fastball', 'Curveball', 'Slider', 'Changeup']
feb_pitches = [8, 3, 0, 1]
feb_spots = [3, 0, 0, 0]

feb_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(feb_spots, feb_pitches)]

#CHANGE THESE
mar_pitches = [99, 44, 10, 6]
mar_spots = [54, 28, 7, 3]

mar_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(mar_spots, mar_pitches)]

apr_pitches = [72, 43, 26, 1]
apr_spots = [44, 26, 16, 1]

apr_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(apr_spots, apr_pitches)]

may_pitches = [21, 5, 7, 1]
may_spots = [16, 2, 5, 1]

may_spot_percentages = [(s / p) * 100 if p != 0 else 0 for s, p in zip(may_spots, may_pitches)]

feb_total_pitches = sum(feb_pitches)
feb_total_spots = sum(feb_spots)
feb_total_percent = (feb_total_spots / feb_total_pitches) * 100

mar_total_pitches = sum(mar_pitches)
mar_total_spots = sum(mar_spots)
mar_total_percent = (mar_total_spots / mar_total_pitches) * 100

apr_total_pitches = sum(apr_pitches)
apr_total_spots = sum(apr_spots)
apr_total_percent = (apr_total_spots / apr_total_pitches) * 100

may_total_pitches = sum(may_pitches)
may_total_spots = sum(may_spots)
may_total_percent = (may_total_spots / may_total_pitches) * 100

feb_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': feb_pitches + [feb_total_pitches],
    'Spots': feb_spots + [feb_total_spots],
    'Spot%': feb_spot_percentages + [feb_total_percent]
})

mar_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': mar_pitches + [mar_total_pitches],
    'Spots': mar_spots + [mar_total_spots],
    'Spot%': mar_spot_percentages + [mar_total_percent]
})

apr_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': apr_pitches + [apr_total_pitches],
    'Spots': apr_spots + [apr_total_spots],
    'Spot%': apr_spot_percentages + [apr_total_percent]
})

may_df = pd.DataFrame({
    'Pitch Type': pitch_types + ['Totals'],
    'Pitches': may_pitches + [may_total_pitches],
    'Spots': may_spots + [may_total_spots],
    'Spot%': may_spot_percentages + [may_total_percent]
})

feb_df['Spot%'] = feb_df['Spot%'].map(lambda x: f"{x:.1f}%")
mar_df['Spot%'] = mar_df['Spot%'].map(lambda x: f"{x:.1f}%")
apr_df['Spot%'] = apr_df['Spot%'].map(lambda x: f"{x:.1f}%")
may_df['Spot%'] = may_df['Spot%'].map(lambda x: f"{x:.1f}%")

season_df = pd.concat([feb_df, mar_df, apr_df, may_df]).groupby('Pitch Type').sum().reset_index()

order = pitch_types + ['Totals']
season_df['Pitch Type'] = pd.Categorical(season_df['Pitch Type'], categories=order, ordered=True)
season_df = season_df.sort_values('Pitch Type')

season_df['Spot%'] = (season_df['Spots'] / season_df['Pitches']) * 100
season_df['Spot%'] = season_df['Spot%'].map(lambda x: f"{x:.1f}%")

#CHANGE NAME and maybe 'hspace'
fig, axs = plt.subplots(3, 2, figsize=(13, 7), gridspec_kw={'hspace': 0.3, 'wspace': 0.1})
fig.suptitle("Jack Welsch Spot% Tables", fontsize=24, fontweight='bold')

header_color = '#6a329f'
total_row_color = '#f0f0f0'

def table(ax, df, title):
    ax.axis('off')
    ax.set_title(title, fontsize=20, fontweight='bold')
    
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    table.auto_set_font_size(False)
    table.set_fontsize(14)
    table.scale(1, 1.55)

    for key, cell in table.get_celld().items():
        if key[0] == 0:
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor(header_color)
        if key[0] == len(df):
            cell.set_fontsize(14)
            cell.set_text_props(weight='bold')
            cell.set_facecolor(total_row_color)

table(axs[0, 0], feb_df, "February")
table(axs[0, 1], mar_df, "March")
table(axs[1, 0], apr_df, "April")
table(axs[1, 1], may_df, "May")
table(axs[2, 0], season_df, "Season")
axs[2, 1].axis('off')

plt.show()
